# %%
import numpy as np
import random
from astropy import units as u
from astropy.coordinates import SkyCoord, EarthLocation, AltAz
from astropy.time import Time
import scipy
import os
import subprocess
import matplotlib.pylab as plt
# %matplotlib inline

os.chdir('/data/des41.a/data/jaortiz/snana-test/do_swaps/')
from make_histograms import make_histogram_vars
from make_histograms import plot_histogram
from make_swaps_arr import make_swaps
from make_swaps_arr import whisker_plot
from parse_dump import findall_KN 
from make_simlib_file import make_simlib

os.chdir('/data/des41.a/data/jaortiz/snana-test/')
from python_all.parse_simlib import parse_simlib
from python_all.python_utilities.des_io import parse_observations

# %%
libid_details, pointings_arr = parse_simlib('simlibs/minion_1016_WFD.simlib')

# %%
#variables
t1 = 2.5 #time period in which we want pointing at KN to occur (days)
t2 = 50 #time period in which we are happy to do compensating swap (days)
max_airmass = 2
max_extra_slew = 110 #in deg

# %%
new_pointings_arr, data, costs, success = amake_swaps(t1, t2, max_airmass, max_extra_slew)
# Out:
# 2 50 2 100
# Number of simulations:  1697
# 0
# Num observed once:  3
# Num KN observed twice or more:  4

# %%
new_pointings_arr, data, no_obs, obs_made, costs, success = two_make_swaps(t1, t2, max_airmass, max_extra_slew, pointings_arr)
# Out:
# 2.5 50 2 110
# Number of simulations:  1697
# 0
# extra overhead time is negative and large: -0.000904847475992 New:  42.7811781618 Old:  120.960000088
# 4 60550.0699 [ 60550.068   60550.0685  60550.0699  60550.0704  60550.0709]
# extra overhead time is negative and large: -0.000329983260514 New:  49.2494462132 Old:  77.7599999215
# 7 61075.2932 [ 61075.2918  61075.2923  61075.2932  61075.2936  61075.2941]
# extra overhead time is negative and large: -2.79041956386 New:  93.3496826399 Old:  241185.6
# 18 59848.9815 [ 59846.1896  59846.19    59848.9815  59848.982   59848.9824]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(220, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(842, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(867, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(219, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1604, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(230, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(830, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(367, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(177, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(829, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(0, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1294, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(122, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(144, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1028, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1027, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1912, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(534, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(670, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(414, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(142, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(140, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(500, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(438, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(62, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1450, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(704, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(746, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2143, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(613, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1277, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(222, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(31, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(612, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(221, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(30, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(617, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(242, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(196, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(140, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(39, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1875, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1319, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(371, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(185, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1985, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(106, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(39, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1840, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(105, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1268, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(8, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(374, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(544, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(124, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(218, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1682, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(440, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(811, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(431, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1789, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(180, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1300, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(140, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(79, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.000250917801219 New:  99.2807020622 Old:  120.960000088
# 35 61139.9913 [ 61139.9894  61139.9899  61139.9913  61139.9917  61139.9922]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(90, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(179, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(78, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2392, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(43, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2042, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(307, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(42, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(306, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1377, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(30, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1161, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(136, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(29, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1160, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(135, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1693, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(10, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(611, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1072, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1429, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1116, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(313, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1115, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.000252037516689 New:  38.7039582875 Old:  60.4799997294
# 39 61776.1674 [ 61776.1658  61776.1667  61776.1674  61776.1682  61776.1689]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(312, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1345, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(445, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(710, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(190, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(444, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(709, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(189, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1737, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(197, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(308, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1232, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(196, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(953, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(291, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(535, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(127, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(290, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(534, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(126, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(689, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(302, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(301, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(36, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(300, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(35, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1733, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(372, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1257, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(103, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(371, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.00045134469939 New:  38.7638178943 Old:  77.7599999215
# 44 60957.1039 [ 60957.1026  60957.103   60957.1039  60957.1044  60957.1048]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1965, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(166, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(925, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(714, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(160, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1889, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(13, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(547, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1066, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.000351380446668 New:  38.7607289191 Old:  69.1199995112
# 46 61739.1827 [ 61739.1814  61739.1819  61739.1827  61739.1831  61739.1836]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(263, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(546, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1065, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2314, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(796, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(750, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(550, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.000447675783619 New:  47.7208126273 Old:  86.4000003319
# 47 62208.1696 [ 62208.1681  62208.1686  62208.1696  62208.1701  62208.1707]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(795, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.000551357902135 New:  38.7626769588 Old:  86.3999997033
# 47 62209.1155 [ 62209.114   62209.1145  62209.1155  62209.116   62209.1165]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(749, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(549, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(217, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2434, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(434, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(525, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(600, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(458, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(417, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(524, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(599, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(416, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1788, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(34, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(658, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(960, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1479, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1479, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1805, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1353, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(198, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(133, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(121, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(747, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(76, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(634, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(37, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2158, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(20, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(100, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2038, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2535, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(320, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(688, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(882, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(600, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(45, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(319, 2) will return an array of dtype('int64')
# ...
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(806, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(234, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(536, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(535, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1013, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1494, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(726, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1878, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1282, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(56, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(342, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(691, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(341, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(810, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.000457575897532 New:  38.2254423747 Old:  77.7599999215
# 1677 59858.2279 [ 59858.2266  59858.227   59858.2279  59858.2283  59858.2288]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1301, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(775, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(10, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(9, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(53, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.00728121444852 New:  70.7430715704 Old:  699.839999923
# 1679 60588.2901 [ 60588.2815  60588.282   60588.2901  60588.2906  60588.2915]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(969, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(548, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.00318121445023 New:  70.7430715704 Old:  345.60000007
# 1679 60588.3084 [ 60588.3039  60588.3044  60588.3084  60588.3089  60588.3233]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(968, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1322, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(171, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2068, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(628, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(488, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(270, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1470, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(708, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(38, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(307, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(390, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(390, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(314, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(891, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(890, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(399, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1278, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1174, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(977, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1297, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(677, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1455, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(559, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(894, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1808, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(709, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(280, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(447, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(693, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.00106530933193 New:  63.4772735648 Old:  155.519999843
# 1693 60732.0337 [ 60732.0314  60732.0319  60732.0337  60732.0341  60732.0346]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(594, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.000360978593127 New:  55.2114492571 Old:  86.3999997033
# 1693 60733.0419 [ 60733.0404  60733.0409  60733.0419  60733.043   60733.0434]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(266, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(279, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(446, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1931, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.0003479683062 New:  47.6955382659 Old:  77.7599999215
# 1695 62673.445 [ 62673.4437  62673.4441  62673.445   62673.4455  62673.4459]
# Num observed once:  33
# Num KN observed twice or more:  1035

# %%
tot = 0
for c in costs:
    c = np.array(c)
    #print len(cost), sum(np.array(cost)<0), sum(cost)
    pos = c[c>0]*24*3600
    neg = c[c<0]*24*3600
    tot += sum(pos)
    
twice = [2.5, 50, 2, 110, 666, 26, 0, 0, 101640.637943]
print tot
# Out:
# 101640.637943

# %%
folder = str(t1) + '_' + str(t2) + '_' + str(max_airmass) + '_' + str(max_extra_slew)

#Save simlib file under new name for different variables and then change .input file
make_simlib(new_pointings_arr, 'simlibs/new_twice_' + folder + '.simlib')

print len(success)



""" 
4_80_2_100
1697 KN

Num observed once:  147
Num KN observed twice or more:  1018

Rejection Statistics: 
	   397 rejected by NEPOCH<1 
	     0 rejected by GENRANGEs 
	   800 rejected by SEARCH-TRIGGER 
	     0 rejected by CUTWIN-SELECTION 
  SEARCH+CUTS Efficiency:  0.2946 +-  0.0111 

  Number of SNe per season AFTER CUTS :    500 +-    22 """
# Out:
# 1035
# ' \n4_80_2_100\n1697 KN\n\nNum observed once:  147\nNum KN observed twice or more:  1018\n\nRejection Statistics: \n\t   397 rejected by NEPOCH<1 \n\t     0 rejected by GENRANGEs \n\t   800 rejected by SEARCH-TRIGGER \n\t     0 rejected by CUTWIN-SELECTION \n  SEARCH+CUTS Efficiency:  0.2946 +-  0.0111 \n\n  Number of SNe per season AFTER CUTS :    500 +-    22 '

# %%
DIR = '/data/des41.b/data/SNDATA_ROOT/SIM/GW170817_AT2017gfo_LSST_WFD/'
#get KN locations of simulated events in snana
file_count = len([f for f in os.walk(DIR).next()[2] if f[-4:] == ".DAT"])
KN_locations = np.zeros([file_count, 3])

# run through all .dat files in the specified directory and get time and location of KN
file_num = 0
for file in os.listdir(DIR):  
    if file.endswith(".DAT"):
        obs, headerdict = parse_observations(DIR + file)
        KN_locations[file_num,:] = [headerdict['PEAKMJD'], headerdict['RA'], headerdict['DECL']]
        file_num += 1    
print 'Number of KN observed by snana: ', len(KN_locations)

print KN_locations[:,0].astype(int)
print np.array(success).astype(int)
# Out:
# Number of KN observed by snana:  57
# [60959 60548 63002 60195 62855 62828 61502 61910 62050 62235 60716 61138
#  63019 61775 62555 61697 61996 60955 61736 63083 62960 62751 61906 60003
#  62576 61530 61107 62026 60129 62601 62265 62333 61747 62770 61792 63185
#  62647 60638 62083 60979 61885 60750 62053 62870 63052 61785 62656 62906
#  61602 63084 60885 59998 60729 62391 60549 59865 61544]
# [60958 60548 61073 63002 60195 62855 62828 62747 61626 61502 61910 62050
#  60716 61138 63019 60590 61775 62555 62042 61697 61996 60955 61736 62208
#  63083 60841 62751 62452 60003 62317 61530 61107 62026 60129 62265 62333
#  61747 60020 62770 62204 61792 60385 59851 63185 62647 62387 60677 62083
#  62000 61885 60748 60750 60564 62053 62870 63052 61785 62656 62906 63084
#  61135 60885 60204 61676 60968 59998 60729 61454 60524 60197 60298 60549
#  59865 62993 59951 62485]

# %%
import subprocess
import os
from astropy import units as u
from astropy.coordinates import SkyCoord, EarthLocation, AltAz
from astropy.time import Time
import scipy
import numpy as np
import matplotlib.pyplot as plt

os.chdir('/data/des41.a/data/jaortiz/snana-test/')
from python_all.parse_simlib import parse_simlib
os.chdir('/data/des41.a/data/jaortiz/snana-test/do_swaps/')
from parse_dump import findall_KN 



def amake_swaps(t1, t2, max_airmass, max_extra_slew):
    os.chdir('/data/des41.a/data/jaortiz/snana-test/')
    print t1, t2, max_airmass, max_extra_slew
    
    success = []
    maybe_obs = []
    
    plt.figure()

    
    allKN = findall_KN()
    KNlist = allKN
    
    os.chdir('/data/des41.a/data/jaortiz/snana-test/')

    #Creates a list of all pointings, with [LIBID, RA, DECL, MJD IDEXPT  FLT GAIN NOISE SKYSIG (pixels)  RATIO  ZPTAVG ZPTERR  MAG]

    #Results analysis 
    #[swap made, observation already scheduled, no observations in next 24hrs, slew angle >70deg, no observations in next week close to KN]

    bands = ['u', 'g', 'r', 'i', 'z', 'Y']
    new_pointings_arr = np.copy(pointings_arr)

    slews = np.zeros([len(KNlist),6])
#     no_obs, obs_made = np.zeros(6, dtype=float), np.zeros(6, dtype=float)
    costs = [ [], [], [], [], [], [] ]

    folder = str(t1) + '_' + str(t2) + '_' + str(max_airmass) + '_' + str(max_extra_slew)

    subprocess.call(["mkdir", "do_swaps/new_pointings_arrays/" + folder])

    
    #logging
    os.chdir('/data/des41.a/data/jaortiz/snana-test/do_swaps/new_pointings_arrays/' + folder + '/')
    log = open('swaps.log', 'w')
    log.write('t1 = %i, t2 = %i, max airmass = %i, max slew angle = %i \n\n' %(t1, t2, max_airmass, max_extra_slew))
    log.write('Number of KN processed: %i \n\n' %len(KNlist))
    log.write('Swap made, KN already scheduled to be observed in next t1 days, KN is not visible in next t1 days, No observations when KN is visible in next t1 days, Closest observation has max slew angle too large, No observation in next t2 days close to KN \n')

    results = np.zeros([6,8]) #must reset variable for each band

    for j, KN in enumerate(KNlist):
        #print '*****************New KN****************', KN
        if j%100 ==0:
            print j
        
        success_count = 0
        
        pointings_later = pointings_arr[KN[0]<pointings_arr[:,3], :]
        pointings_nextday = pointings_later[pointings_later[:,3]<(KN[0]+t1)]
        #print 'Number of pointings in next t1 days: ', len(pointings_nextday)
        y1 = np.full(len(pointings_nextday), 7)
        plt.scatter(pointings_nextday[:,3], y1, marker=1)
        
        obs_times = when_observable(KN, max_airmass, t1)
        #print 'Number of observable times: ', len(obs_times)
        y = np.zeros(len(obs_times))
        plt.scatter(obs_times, y, marker='x')

        for band in range(6):
            #print '%s Filter' %bands[band]
            band_pointings_arr = pointings_arr[pointings_arr[:,5]==band, :]

            #when is the KN going to be visible? Check the next 24 hours in 0.5 hour intervals


            #Are we scheduled to observe this event anyway? If not find the closest observation in the next 24 hours
            closest_obs, slew_to_KN, original_overhead_time = get_closest_obs(pointings_arr, band_pointings_arr, KN, obs_times, t1, max_extra_slew, band)
            slews[j, band] = slew_to_KN

            if type(original_overhead_time) == int:
                if original_overhead_time == 0:
                    results[band,3] += 1 #no observations in next 24hrs
                    #print 'Swap failed as no observations when KN is visible in next %i day(s)' %t1
                    continue
                if original_overhead_time == 1:
                    results[band,1] += 1 #observation already exists
                    #print 'No swap required as observation already exists with slew to KN: %f' %slew_to_KN
                    success_count += 1
                    continue
                if original_overhead_time == 2:
                    results[band,4] += 1 #slew angle > max_extra_slew deg
                    #print 'Swap failed as closest observation has angsep: %f > 70deg' %slew_to_KN
                    continue
                if original_overhead_time == 3:
                    results[band,2] += 1 #slew angle > max_extra_slew deg
                    #print 'Swap failed as KN not visible in next %i day(s)' %t1
                    continue

            #Search for future pointing at KN location (within 0.5deg) in next 7 days.
            #if we have made it this far then we want to do a swap unless there is no observation in the future we can swap with
            pointing_to_swap, min_angsep_lt = find_later_pointing(band_pointings_arr, KN, t2)
            if type(pointing_to_swap) == int:
                results[band,5] += 1 #note that no swap because there is no pointing close to KN in next week
                #print 'Swap failed as no observation in next %i days close to KN. Closest obs at %f' %(t2, min_angsep_lt)
                continue

            #What is the cost in slew time of swapping these pointings?
            extra_overhead_time, swap_ang = cost(pointing_to_swap, closest_obs, original_overhead_time, pointings_arr, j, KN)
            costs[band].append(extra_overhead_time)

            #swap libid, ra and decl 
            new_pointings_arr = swap_obs(new_pointings_arr, closest_obs, pointing_to_swap)
            results[band,0] += 1
            #print j, 'Swap done. t1swap= ', closest_obs[3]-KN[0], 'swap_angle= ', swap_ang
            success_count += 1

        plt.yticks(np.arange(8),['KN is visible', 'u', 'g', 'r', 'i', 'z', 'Y', 'observation in any band'])
        #plt.show()
        
        if success_count ==1:
            maybe_obs.append(KN[0])
        if success_count > 1:
            success.append(KN[0])

    results_frac = results/float(len(KNlist))
#     no_obs[band] = results_frac[2] + results_frac[3] #to display this figure on graph too
#     obs_made[band] = results_frac[1] 
    for band in range(len(bands)):
        log.write('%s: %.3f, %.3f, %.3f, %.3f, %.3f, %.3f \n' %(bands[band],results_frac[band,0],results_frac[band,1],results_frac[band,2],\
                                                                results_frac[band,3],results_frac[band,4],results_frac[band,5]) )

    #        print '\n', '****************** %s Filter *********************' %bands[band]
    #        print 'Number of KN processed: %i \n' %len(KNlist)
    #        print 'Swap made: %.1f  \nNo swap made because... \n    Observation already scheduled: %.1f ' %(results_frac[0], results_frac[1])
    #        print '    No observations in next %i day(s): %.1f ' %(t1,results_frac[3])
    #        print '    Swap failed as extra slew required > %i deg: %.1f ' %(max_extra_slew,results_frac[4])
    #        print '    No observation in next %i days close to KN: %.1f ' %(t2, results_frac[5])
    #        print  '***************************************************'

    #     log.close()

    print 'Num observed once: ', len(maybe_obs)
    print 'Num KN observed twice or more: ', len(success)
        
    data = [slews[:,0][~np.isnan(slews[:,0])], slews[:,1][~np.isnan(slews[:,1])], slews[:,2][~np.isnan(slews[:,2])], \
                 slews[:,3][~np.isnan(slews[:,3])], slews[:,4][~np.isnan(slews[:,4])], slews[:,5][~np.isnan(slews[:,5])] ]
    

    
    
    tot = 0
    for c in costs:
        c = np.array(c)
        #print len(cost), sum(np.array(cost)<0), sum(cost)
        pos = c[c>0]*24*3600
        neg = c[c<0]*24*3600
        tot += sum(pos)
    
    summary = np.array([t1, t2, max_airmass, max_extra_slew, 0,0,0,0,tot, len(success)])

    os.chdir('/data/des41.a/data/jaortiz/snana-test/')
    np.save("do_swaps/new_pointings_arrays/" + folder + '/new_pointings_arr', new_pointings_arr)
    np.save("do_swaps/new_pointings_arrays/" + folder + '/costs', costs)
    np.save("do_swaps/new_pointings_arrays/" + folder + '/success', success)
    np.save("do_swaps/new_pointings_arrays/" + folder + '/data', data)
    np.save("do_swaps/new_pointings_arrays/" + folder + '/summary', summary)

    return new_pointings_arr, data, costs, success


def when_observable(KN, max_airmass, t1):#when is the KN going to be visible? Check the next 24 hours in 0.5 hour intervals

    lsst_location = EarthLocation(lat=-30.2446*u.deg, lon=-70.7494*u.deg, height=2663*u.m)
    times = np.arange(KN[0], KN[0]+t1, 1/48.) #30 minute intervals in next 24 hours
    time = Time(times, format='mjd')
    KN_loc = SkyCoord(ra=KN[1] * u.degree, dec=KN[2] * u.degree)
    KNaltaz = KN_loc.transform_to(AltAz(obstime=time,location=lsst_location))  
    altitude = KNaltaz.alt.deg
    
    #put limit on airmass, Could be below ~2
    zenith_ang = 90 - altitude #in deg
    zenith_ang_rad = zenith_ang * np.pi / 180
    airmass = 1 / np.cos(zenith_ang_rad)
    
    observable = (airmass<max_airmass).astype(int) #observable if altitude in sky is >5deg
    for i,t in enumerate(times):
        if airmass[i] <0:
            observable[i]=0
    
    #ind = np.nonzero(times)
    obs_times = observable*times
    ind = np.array(observable.astype(bool))
    obs_times = obs_times[ind]
    
    return obs_times 


def get_closest_obs(pointings_arr, band_pointings_arr, KN, obs_times, t1, max_extra_slew, band):
    #Are we scheduled to observe this event anyway? If not find the closest observation in the next 24 hours

    #get pointings in the next week
    pointings_later = band_pointings_arr[KN[0]<band_pointings_arr[:,3], :]
    pointings_nextday_possible = pointings_later[pointings_later[:,3]<(KN[0]+t1)]
    
    #print '%i possible pointings in next t1 days' %len(pointings_nextday_possible)#, pointings_nextday_possible[:,3]
    if len(pointings_nextday_possible) != 0:
        y = np.full(len(pointings_nextday_possible[:,3]), band+1)
        plt.scatter(pointings_nextday_possible[:,3], y, marker='x')
    
    #only consider pointings in next day when KN is observable
    if len(obs_times) == 0: #if there are no observable times then we still need to create variable pointings_nextday
        pointings_nextday = []
        closest_obs, original_overhead_time, slew_to_KN = 0,3, np.nan
    else:
        for i,time in enumerate(obs_times):
            add_maybe = pointings_nextday_possible[pointings_nextday_possible[:,3]<(time+ 1/48.)]
            add = add_maybe[add_maybe[:,3]>time]
            if i==0:
                pointings_nextday = np.copy(add)
            else:
                pointings_nextday = np.vstack((pointings_nextday, add))
    
        #pointings_not_observable = [pointing for pointing in pointings_nextday_possible if pointing not in pointings_nextday]
        #print len(pointings_nextday_possible), len(pointings_not_observable), len(pointings_nextday)
    if len(pointings_nextday_possible) != 0: #for checking    
        pointings_lcs = SkyCoord(ra=pointings_nextday_possible[:,1] * u.degree, dec=pointings_nextday_possible[:,2] * u.degree)
        KN_loc = SkyCoord(ra=KN[1] * u.degree, dec=KN[2] * u.degree)
        ags = KN_loc.separation(pointings_lcs).deg
                
    
    if len(pointings_nextday) == 0:
        if len(obs_times) != 0 : #if no pointings in the next 24hrs, due to no pointings
            closest_obs, original_overhead_time, slew_to_KN = 0,0, np.nan
    else:
        
        #print 'Number of pointings in next day when KN is observable', len(pointings_nextday[:,3])

        #get angles between all of pointings and KN
        pointings_locs = SkyCoord(ra=pointings_nextday[:,1] * u.degree, dec=pointings_nextday[:,2] * u.degree)
        KN_loc = SkyCoord(ra=KN[1] * u.degree, dec=KN[2] * u.degree)
        angsep = KN_loc.separation(pointings_locs).deg
        
        #find closest pointing within 24hours for swap
        closest_obs = pointings_nextday[np.argmin(angsep),:]
        slew_to_KN = np.min(angsep)
        
        row_of_pointingsarr = np.argwhere(pointings_arr[:,4]==closest_obs[4])[0][0]
        original_overhead_time = pointings_arr[row_of_pointingsarr,3] - pointings_arr[row_of_pointingsarr-1,3]
        
        #check if we are scheduled to observe this event anyway
        #observations_arg = np.argwhere(angsep < np.sqrt(9.6/np.pi))
        #KN_observations = pointings_nextday[observations_arg,:] #observations made of KN, if any
        if slew_to_KN < np.sqrt(9.6/np.pi):
            original_overhead_time = 1 #no swap because observation already exists
        if slew_to_KN > max_extra_slew:
            original_overhead_time = 2 #no swap because smallest slew angle was too large

    if len(pointings_nextday_possible) != 0:
        if np.min(ags) < np.sqrt(9.6/np.pi) and np.min(ags) != slew_to_KN:
            print 'Problem', np.min(ags), slew_to_KN
            mjd = pointings_nextday_possible[np.argmin(ags), 3]
            print mjd, obs_times
            lsst_location = EarthLocation(lat=-32.344633333333334*u.deg, lon=-77.34941666666666*u.deg, height=2652*u.m)
            times = np.arange(KN[0], KN[0]+t1, 1/48.) #30 minute intervals in next 24 hours
            time = Time(mjd, format='mjd')
            KN_loc = SkyCoord(ra=KN[1] * u.degree, dec=KN[2] * u.degree)
            KNaltaz = KN_loc.transform_to(AltAz(obstime=time,location=lsst_location))  
            altitude = KNaltaz.alt.deg

            #put limit on airmass, Could be below ~2
            zenith_ang = 90 - altitude #in deg
            zenith_ang_rad = zenith_ang * np.pi / 180
            airmass = 1 / np.cos(zenith_ang_rad)
            print 'airmass is ', airmass
    
    return closest_obs, slew_to_KN, original_overhead_time



def find_later_pointing(pointings_arr, KN, t2):
    #Search for future pointing at KN location (within 0.5deg) in next 7 days.
    #if we have made it this far then we want to do a swap unless there is no observation in the future we can swap with

    #get pointings in the next week
    pointings_later = pointings_arr[KN[0]<pointings_arr[:,3], :]
    pointings_nextweek = pointings_later[pointings_later[:,3]<(KN[0]+t2)]
    
    nextweek_locs = SkyCoord(ra=pointings_nextweek[:,1] * u.degree, dec=pointings_nextweek[:,2] * u.degree)
    KN_loc = SkyCoord(ra=KN[1] * u.degree, dec=KN[2] * u.degree)
    angsep_longterm = KN_loc.separation(nextweek_locs).deg
    min_angsep_lt = np.min(angsep_longterm)
    if np.min(angsep_longterm) > np.sqrt(9.6/np.pi): #Require KN to be inside observation as we will swap ra,decl
        pointing_to_swap = 0 #no observations in next week to swap with
    else:
        possible_swap_arg = np.argwhere(angsep_longterm < np.sqrt(9.6/np.pi)) 
        pointing_to_swap = pointings_nextweek[possible_swap_arg,:][0][0] #get pointing to swap
        
    return pointing_to_swap, min_angsep_lt




def cost(pointing_to_swap, closest_obs, original_overhead_time, pointings_arr, j, KN):
    #What is the cost in slew time of swapping these pointings?

    swap_to_now = SkyCoord(ra=closest_obs[1] * u.degree, dec=closest_obs[2] * u.degree)
    swap_to_later = SkyCoord(ra=pointing_to_swap[1] * u.degree, dec=pointing_to_swap[2] * u.degree)
    swap_angle = swap_to_now.separation(swap_to_later).deg 
    const1, const2 = 33.5250434/(24*3600.), 1.67705303/(24*3600.) #these numbers must be changed
    new_overhead_time = const1 + const2*swap_angle
    extra_overhead_time = new_overhead_time - original_overhead_time #units of days
    if original_overhead_time <0:
        print 'original overhead time is less than zero!'
    if extra_overhead_time < -0.00025:
        print 'extra overhead time is negative and large:', extra_overhead_time, 'New: ', new_overhead_time*3600*24, 'Old: ', original_overhead_time*3600*24
        row_of_pointingsarr = np.argwhere(pointings_arr[:,4]==closest_obs[4])[0][0]
        print j, closest_obs[3], pointings_arr[row_of_pointingsarr-2:row_of_pointingsarr+3,3]
    #if extra_overhead_time > 0.0005:
    #    print 'extra overhead time is large. New: ', new_overhead_time*3600*24, 'Old: ', original_overhead_time*3600*24

        
    return extra_overhead_time, swap_angle


def swap_obs(new_pointings_arr, closest_obs, pointing_to_swap): #swap libid, ra and decl 
    
    for i in range(len(new_pointings_arr)):
        if new_pointings_arr[i,4]==closest_obs[4]:
            new_pointings_arr[i,0:3] = pointing_to_swap[0:3]
        if new_pointings_arr[i,4]==pointing_to_swap[4]:
            new_pointings_arr[i,0:3] = closest_obs[0:3]

    return new_pointings_arr

# %%
import subprocess
import os
from astropy import units as u
from astropy.coordinates import SkyCoord, EarthLocation, AltAz
from astropy.time import Time
import scipy
import numpy as np
import matplotlib.pyplot as plt

os.chdir('/data/des41.a/data/jaortiz/snana-test/')
from python_all.parse_simlib import parse_simlib
os.chdir('/data/des41.a/data/jaortiz/snana-test/do_swaps/')
from parse_dump import findall_KN 



def two_make_swaps(t1, t2, max_airmass, max_extra_slew, pointings_arr):
    os.chdir('/data/des41.a/data/jaortiz/snana-test/')
    print t1, t2, max_airmass, max_extra_slew
    
    success = []
    maybe_obs = []
    
    plt.figure()

    
    allKN = findall_KN()
    KNlist = allKN
    
    os.chdir('/data/des41.a/data/jaortiz/snana-test/')

    #Creates a list of all pointings, with [LIBID, RA, DECL, MJD IDEXPT  FLT GAIN NOISE SKYSIG (pixels)  RATIO  ZPTAVG ZPTERR  MAG]

    #Results analysis 
    #[swap made, observation already scheduled, no observations in next 24hrs, slew angle >70deg, no observations in next week close to KN]

    bands = ['u', 'g', 'r', 'i', 'z', 'Y']
    new_pointings_arr = np.copy(pointings_arr)

    slews = np.zeros([len(KNlist),6])
#     no_obs, obs_made = np.zeros(6, dtype=float), np.zeros(6, dtype=float)
    costs = [ [], [], [], [], [], [] ]

    results = np.zeros([6,8]) #must reset variable for each band

    for j, KN in enumerate(KNlist):
        #print '*****************New KN****************', KN
        if j%200 ==0:
            print j
        
        success_count = 0
        
        pointings_later = pointings_arr[KN[0]<pointings_arr[:,3], :]
        pointings_nextday = pointings_later[pointings_later[:,3]<(KN[0]+t1)]
        #print 'Number of pointings in next t1 days: ', len(pointings_nextday)
        y1 = np.full(len(pointings_nextday), 7)
        plt.scatter(pointings_nextday[:,3], y1, marker=1)
        
        obs_times = when_observable(KN, max_airmass, t1)
        #print 'Number of observable times: ', len(obs_times)
        y = np.zeros(len(obs_times))
        plt.scatter(obs_times, y, marker='x')
        
        for loop in range(2): 
            for band in range(6):
                #print '%s Filter' %bands[band]
                band_pointings_arr = pointings_arr[pointings_arr[:,5]==band, :]

                #when is the KN going to be visible? Check the next 24 hours in 0.5 hour intervals


                #Are we scheduled to observe this event anyway? If not find the closest observation in the next 24 hours
                closest_obs, slew_to_KN, original_overhead_time = get_closest_obs(pointings_arr, band_pointings_arr, KN, obs_times, t1, max_extra_slew, band)
                slews[j, band] = slew_to_KN

                if type(original_overhead_time) == int:
                    if original_overhead_time == 0:
                        results[band,3] += 1 #no observations in next 24hrs
                        #print 'Swap failed as no observations when KN is visible in next %i day(s)' %t1
                        continue
                    if original_overhead_time == 1:
                        results[band,1] += 1 #observation already exists
                        #print 'No swap required as observation already exists with slew to KN: %f' %slew_to_KN
                        success_count += 1
                        continue
                    if original_overhead_time == 2:
                        results[band,4] += 1 #slew angle > max_extra_slew deg
                        #print 'Swap failed as closest observation has angsep: %f > 70deg' %slew_to_KN
                        continue
                    if original_overhead_time == 3:
                        results[band,2] += 1 #slew angle > max_extra_slew deg
                        #print 'Swap failed as KN not visible in next %i day(s)' %t1
                        continue

                #Search for future pointing at KN location (within 0.5deg) in next 7 days.
                #if we have made it this far then we want to do a swap unless there is no observation in the future we can swap with
                pointing_to_swap, min_angsep_lt = find_later_pointing(band_pointings_arr, KN, t2)
                if type(pointing_to_swap) == int:
                    results[band,5] += 1 #note that no swap because there is no pointing close to KN in next week
                    #print 'Swap failed as no observation in next %i days close to KN. Closest obs at %f' %(t2, min_angsep_lt)
                    continue

                #What is the cost in slew time of swapping these pointings?
                extra_overhead_time, swap_ang = cost(pointing_to_swap, closest_obs, original_overhead_time, pointings_arr, j, KN)
                costs[band].append(extra_overhead_time)

                #swap libid, ra and decl 
                new_pointings_arr = swap_obs(new_pointings_arr, closest_obs, pointing_to_swap)
                #make sure we don't do the same swap twice
                pointings_arr = np.delete(pointings_arr, np.argwhere(pointings_arr[:,4]==closest_obs[4])[0][0], 0) 
                pointings_arr = np.delete(pointings_arr, np.argwhere(pointings_arr[:,4]==pointing_to_swap[4])[0][0], 0) 
                
                results[band,0] += 1
                #print j, 'Swap done. t1swap= ', closest_obs[3]-KN[0], 'swap_angle= ', swap_ang
                success_count += 1

            plt.yticks(np.arange(8),['KN is visible', 'u', 'g', 'r', 'i', 'z', 'Y', 'observation in any band'])
            #plt.show()

        if success_count ==1:
            maybe_obs.append(KN[0])
        if success_count > 1:
            success.append(KN[0])
    


    results_frac = results/float(len(KNlist))
#     no_obs[band] = results_frac[2] + results_frac[3] #to display this figure on graph too
#     obs_made[band] = results_frac[1] 

    #log.write('%s: %.3f, %.3f, %.3f, %.3f, %.3f, %.3f \n' %(bands[band],results_frac[0],results_frac[1],results_frac[2],results_frac[3],results_frac[4],results_frac[5]) )

    #        print '\n', '****************** %s Filter *********************' %bands[band]
    #        print 'Number of KN processed: %i \n' %len(KNlist)
    #        print 'Swap made: %.1f  \nNo swap made because... \n    Observation already scheduled: %.1f ' %(results_frac[0], results_frac[1])
    #        print '    No observations in next %i day(s): %.1f ' %(t1,results_frac[3])
    #        print '    Swap failed as extra slew required > %i deg: %.1f ' %(max_extra_slew,results_frac[4])
    #        print '    No observation in next %i days close to KN: %.1f ' %(t2, results_frac[5])
    #        print  '***************************************************'

    #     log.close()

    print 'Num observed once: ', len(maybe_obs)
    print 'Num KN observed twice or more: ', len(success)
        
    data = [slews[:,0][~np.isnan(slews[:,0])], slews[:,1][~np.isnan(slews[:,1])], slews[:,2][~np.isnan(slews[:,2])], \
                 slews[:,3][~np.isnan(slews[:,3])], slews[:,4][~np.isnan(slews[:,4])], slews[:,5][~np.isnan(slews[:,5])] ]
    
    no_obs, obs_made = 0,0
    

    return new_pointings_arr, data, no_obs, obs_made, costs, success


def when_observable(KN, max_airmass, t1):#when is the KN going to be visible? Check the next 24 hours in 0.5 hour intervals

    lsst_location = EarthLocation(lat=-30.2446*u.deg, lon=-70.7494*u.deg, height=2663*u.m)
    times = np.arange(KN[0], KN[0]+t1, 1/48.) #30 minute intervals in next 24 hours
    time = Time(times, format='mjd')
    KN_loc = SkyCoord(ra=KN[1] * u.degree, dec=KN[2] * u.degree)
    KNaltaz = KN_loc.transform_to(AltAz(obstime=time,location=lsst_location))  
    altitude = KNaltaz.alt.deg
    
    #put limit on airmass, Could be below ~2
    zenith_ang = 90 - altitude #in deg
    zenith_ang_rad = zenith_ang * np.pi / 180
    airmass = 1 / np.cos(zenith_ang_rad)
    
    observable = (airmass<max_airmass).astype(int) #observable if altitude in sky is >5deg
    for i,t in enumerate(times):
        if airmass[i] <0:
            observable[i]=0
    
    #ind = np.nonzero(times)
    obs_times = observable*times
    ind = np.array(observable.astype(bool))
    obs_times = obs_times[ind]
    
    return obs_times 


def get_closest_obs(pointings_arr, band_pointings_arr, KN, obs_times, t1, max_extra_slew, band):
    #Are we scheduled to observe this event anyway? If not find the closest observation in the next 24 hours

    #get pointings in the next week
    pointings_later = band_pointings_arr[KN[0]<band_pointings_arr[:,3], :]
    pointings_nextday_possible = pointings_later[pointings_later[:,3]<(KN[0]+t1)]
    
    #print '%i possible pointings in next t1 days' %len(pointings_nextday_possible)#, pointings_nextday_possible[:,3]
    if len(pointings_nextday_possible) != 0:
        y = np.full(len(pointings_nextday_possible[:,3]), band+1)
        plt.scatter(pointings_nextday_possible[:,3], y, marker='x')
    
    #only consider pointings in next day when KN is observable
    if len(obs_times) == 0: #if there are no observable times then we still need to create variable pointings_nextday
        pointings_nextday = []
        closest_obs, original_overhead_time, slew_to_KN = 0,3, np.nan
    else:
        for i,time in enumerate(obs_times):
            add_maybe = pointings_nextday_possible[pointings_nextday_possible[:,3]<(time+ 1/48.)]
            add = add_maybe[add_maybe[:,3]>time]
            if i==0:
                pointings_nextday = np.copy(add)
            else:
                pointings_nextday = np.vstack((pointings_nextday, add))
    
        #pointings_not_observable = [pointing for pointing in pointings_nextday_possible if pointing not in pointings_nextday]
        #print len(pointings_nextday_possible), len(pointings_not_observable), len(pointings_nextday)
    if len(pointings_nextday_possible) != 0: #for checking    
        pointings_lcs = SkyCoord(ra=pointings_nextday_possible[:,1] * u.degree, dec=pointings_nextday_possible[:,2] * u.degree)
        KN_loc = SkyCoord(ra=KN[1] * u.degree, dec=KN[2] * u.degree)
        ags = KN_loc.separation(pointings_lcs).deg
                
    
    if len(pointings_nextday) == 0:
        if len(obs_times) != 0 : #if no pointings in the next 24hrs, due to no pointings
            closest_obs, original_overhead_time, slew_to_KN = 0,0, np.nan
    else:
        
        #print 'Number of pointings in next day when KN is observable', len(pointings_nextday[:,3])

        #get angles between all of pointings and KN
        pointings_locs = SkyCoord(ra=pointings_nextday[:,1] * u.degree, dec=pointings_nextday[:,2] * u.degree)
        KN_loc = SkyCoord(ra=KN[1] * u.degree, dec=KN[2] * u.degree)
        angsep = KN_loc.separation(pointings_locs).deg
        
        #find closest pointing within 24hours for swap
        closest_obs = pointings_nextday[np.argmin(angsep),:]
        slew_to_KN = np.min(angsep)
        
        row_of_pointingsarr = np.argwhere(pointings_arr[:,4]==closest_obs[4])[0][0]
        original_overhead_time = pointings_arr[row_of_pointingsarr,3] - pointings_arr[row_of_pointingsarr-1,3]
        
        #check if we are scheduled to observe this event anyway
        #observations_arg = np.argwhere(angsep < np.sqrt(9.6/np.pi))
        #KN_observations = pointings_nextday[observations_arg,:] #observations made of KN, if any
        if slew_to_KN < np.sqrt(9.6/np.pi):
            original_overhead_time = 1 #no swap because observation already exists
        if slew_to_KN > max_extra_slew:
            original_overhead_time = 2 #no swap because smallest slew angle was too large

    if len(pointings_nextday_possible) != 0:
        if np.min(ags) < np.sqrt(9.6/np.pi) and np.min(ags) != slew_to_KN:
            print 'Problem', np.min(ags), slew_to_KN
            mjd = pointings_nextday_possible[np.argmin(ags), 3]
            print mjd, obs_times
            lsst_location = EarthLocation(lat=-32.344633333333334*u.deg, lon=-77.34941666666666*u.deg, height=2652*u.m)
            times = np.arange(KN[0], KN[0]+t1, 1/48.) #30 minute intervals in next 24 hours
            time = Time(mjd, format='mjd')
            KN_loc = SkyCoord(ra=KN[1] * u.degree, dec=KN[2] * u.degree)
            KNaltaz = KN_loc.transform_to(AltAz(obstime=time,location=lsst_location))  
            altitude = KNaltaz.alt.deg

            #put limit on airmass, Could be below ~2
            zenith_ang = 90 - altitude #in deg
            zenith_ang_rad = zenith_ang * np.pi / 180
            airmass = 1 / np.cos(zenith_ang_rad)
            print 'airmass is ', airmass
    
    return closest_obs, slew_to_KN, original_overhead_time



def find_later_pointing(pointings_arr, KN, t2):
    #Search for future pointing at KN location (within 0.5deg) in next 7 days.
    #if we have made it this far then we want to do a swap unless there is no observation in the future we can swap with

    #get pointings in the next week
    pointings_later = pointings_arr[KN[0]<pointings_arr[:,3], :]
    pointings_nextweek = pointings_later[pointings_later[:,3]<(KN[0]+t2)]
    
    nextweek_locs = SkyCoord(ra=pointings_nextweek[:,1] * u.degree, dec=pointings_nextweek[:,2] * u.degree)
    KN_loc = SkyCoord(ra=KN[1] * u.degree, dec=KN[2] * u.degree)
    angsep_longterm = KN_loc.separation(nextweek_locs).deg
    min_angsep_lt = np.min(angsep_longterm)
    if np.min(angsep_longterm) > np.sqrt(9.6/np.pi): #Require KN to be inside observation as we will swap ra,decl
        pointing_to_swap = 0 #no observations in next week to swap with
    else:
        possible_swap_arg = np.argwhere(angsep_longterm < np.sqrt(9.6/np.pi)) 
        pointing_to_swap = pointings_nextweek[possible_swap_arg,:][0][0] #get pointing to swap
        
    return pointing_to_swap, min_angsep_lt




def cost(pointing_to_swap, closest_obs, original_overhead_time, pointings_arr, j, KN):
    #What is the cost in slew time of swapping these pointings?

    swap_to_now = SkyCoord(ra=closest_obs[1] * u.degree, dec=closest_obs[2] * u.degree)
    swap_to_later = SkyCoord(ra=pointing_to_swap[1] * u.degree, dec=pointing_to_swap[2] * u.degree)
    swap_angle = swap_to_now.separation(swap_to_later).deg 
    const1, const2 = 33.5250434/(24*3600.), 1.67705303/(24*3600.) #these numbers must be changed
    new_overhead_time = const1 + const2*swap_angle
    extra_overhead_time = new_overhead_time - original_overhead_time #units of days
    if original_overhead_time <0:
        print 'original overhead time is less than zero!'
    if extra_overhead_time < -0.00025:
        print 'extra overhead time is negative and large:', extra_overhead_time, 'New: ', new_overhead_time*3600*24, 'Old: ', original_overhead_time*3600*24
        row_of_pointingsarr = np.argwhere(pointings_arr[:,4]==closest_obs[4])[0][0]
        print j, closest_obs[3], pointings_arr[row_of_pointingsarr-2:row_of_pointingsarr+3,3]
    #if extra_overhead_time > 0.0005:
    #    print 'extra overhead time is large. New: ', new_overhead_time*3600*24, 'Old: ', original_overhead_time*3600*24

        
    return extra_overhead_time, swap_angle


def swap_obs(new_pointings_arr, closest_obs, pointing_to_swap): #swap libid, ra and decl 
    
    for i in range(len(new_pointings_arr)):
        if new_pointings_arr[i,4]==closest_obs[4]:
            new_pointings_arr[i,0:3] = pointing_to_swap[0:3]
        if new_pointings_arr[i,4]==pointing_to_swap[4]:
            new_pointings_arr[i,0:3] = closest_obs[0:3]

    return new_pointings_arr
