# %%
import numpy as np
import random
from astropy import units as u
from astropy.coordinates import SkyCoord
import scipy
import os
import subprocess
import matplotlib.pylab as plt
import logging
# %matplotlib inline

os.chdir('/data/des41.a/data/jaortiz/snana-test/do_swaps/')
from make_histograms import make_histogram_vars
from make_histograms import plot_histogram
from amake_swaps_arr import amake_swaps
from make_swaps_arr import whisker_plot
from parse_dump import findall_KN 
from make_simlib_file import make_simlib

os.chdir('/data/des41.a/data/jaortiz/snana-test/')
from python_all.parse_simlib import parse_simlib
from python_all.python_utilities.des_io import parse_observations

# %%
#variables
t1 = 2.5 #time period in which we want pointing at KN to occur (days)
t2 = 50 #time period in which we are happy to do compensating swap (days)
max_airmass = 2
max_extra_slew = 30 #in deg

# %%
libid_details, pointings_arr = parse_simlib('simlibs/minion_1016_WFD.simlib')

new_pointings_arr, data, costs, success = amake_swaps(t1, t2, max_airmass, max_extra_slew, pointings_arr)

folder = str(t1) + '_' + str(t2) + '_' + str(max_airmass) + '_' + str(max_extra_slew)

#Save simlib file under new name for different variables and then change .input file
make_simlib(new_pointings_arr, 'simlibs/new_' + folder + '.simlib')
# Out:
# 2.5 50 2 30
# Number of simulations:  1697
# 0
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1233, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# WARNING: ErfaWarning: ERFA function "utctai" yielded 120 of "dubious year (Note 3)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "taiutc" yielded 120 of "dubious year (Note 4)" [astropy._erfa.core]
# WARNING: ErfaWarning: ERFA function "apio13" yielded 120 of "dubious year (Note 2)" [astropy._erfa.core]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(921, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(223, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1322, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(918, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(360, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2021, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1062, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1061, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(289, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2250, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1051, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(348, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(57, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2631, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2197, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1459, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(856, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1726, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(950, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(627, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(116, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1141, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(728, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1551, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(779, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(273, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(711, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(105, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1755, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(371, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1115, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(269, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1102, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2423, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(103, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(365, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1882, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(73, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1621, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(769, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(650, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2689, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1254, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1396, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1943, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(843, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(868, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(220, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1604, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(830, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(177, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1294, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1028, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1912, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1450, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(704, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(746, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2143, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(613, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1277, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(222, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(242, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(140, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1875, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1319, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(371, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1985, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1840, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1268, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(374, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(124, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1682, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(811, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1791, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1300, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2394, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2044, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1377, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(30, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1161, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(136, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1693, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(611, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1072, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1429, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1116, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(313, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1345, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(445, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(190, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1737, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1232, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(535, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1733, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1257, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1965, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(166, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(925, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(160, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1889, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1066, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.000351380446668 New:  38.7607289191 Old:  69.1199995112
# 46 61739.1827 [ 61739.1814  61739.1819  61739.1827  61739.1831  61739.1836]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(263, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2314, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(750, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.000447675783619 New:  47.7208126273 Old:  86.4000003319
# 47 62208.1696 [ 62208.1681  62208.1686  62208.1696  62208.1701  62208.1707]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2434, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(434, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(458, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(417, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1788, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1479, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1479, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1805, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1353, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(198, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(634, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2158, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2038, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2535, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(320, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(688, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(882, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(600, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1810, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(369, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(490, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(751, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1476, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(348, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(101, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(331, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(155, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.000354790521173 New:  38.4660991105 Old:  69.1200001398
# 59 62454.098 [ 62454.0967  62454.0972  62454.098   62454.0991  62454.1009]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1595, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1595, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1738, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(138, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1339, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(166, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2107, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1074, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1129, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(609, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1245, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1760, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1740, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(565, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1801, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(860, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(431, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1958, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(119, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(783, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(182, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2413, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(285, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(914, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(849, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(315, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1634, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1024, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(510, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(587, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(341, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(8, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1667, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1287, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(197, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(76, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2025, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(97, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(516, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1412, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(623, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1004, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(163, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2277, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1185, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# ...
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1256, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1973, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(910, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(900, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1831, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1735, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1679, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(377, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(878, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(301, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(577, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2335, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1873, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1490, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(816, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(12, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2305, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(193, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(625, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(323, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1105, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1068, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1534, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1394, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1404, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1374, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1248, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(219, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(806, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(234, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1018, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1869, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1494, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1287, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1914, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(691, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(781, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1795, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(53, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(549, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.00728121444852 New:  70.7430715704 Old:  699.839999923
# 1679 60588.2901 [ 60588.2815  60588.282   60588.2901  60588.2906  60588.2915]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(979, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2248, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1324, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(626, 3) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(171, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(2077, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1040, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(708, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(396, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(317, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(891, 1) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1281, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(981, 6) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1301, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(677, 2) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1818, 7) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.00106530933193 New:  63.4772735648 Old:  155.519999843
# 1693 60732.0337 [ 60732.0314  60732.0319  60732.0337  60732.0341  60732.0346]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(594, 4) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# extra overhead time is negative and large: -0.000360978593127 New:  55.2114492571 Old:  86.3999997033
# 1693 60733.0419 [ 60733.0404  60733.0409  60733.0419  60733.043   60733.0434]
# /cvmfs/des.opensciencegrid.org/fnal/anaconda2/envs/default/lib/python2.7/site-packages/numpy/core/numeric.py:301: FutureWarning: in the future, full(1941, 5) will return an array of dtype('int64')
#   format(shape, fill_value, array(fill_value).dtype), FutureWarning)
# Num observed once:  329
# Num KN observed twice or more:  682

# %%
os.chdir('/data/des41.a/data/jaortiz/snana-test/')


summary = np.load('do_swaps/new_pointings_arrays/' + folder + '/summary.npy')
print summary
# Out:
# [  8.00000000e-01   5.00000000e+01   2.00000000e+00   1.10000000e+02
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    4.19588035e+04   4.86000000e+02]

# %%
os.chdir('/data/des41.a/data/jaortiz/snana-test/')

folder = str(t1) + '_' + str(t2) + '_' + str(max_airmass) + '_' + str(max_extra_slew)

np.save('do_swaps/new_pointings_arrays/' + folder + '/new_pointings_arr', new_pointings_arr)
np.save('do_swaps/new_pointings_arrays/' + folder + '/data', data)
np.save('do_swaps/new_pointings_arrays/' + folder + '/no_obs', no_obs)
np.save('do_swaps/new_pointings_arrays/' + folder + '/obs_made', obs_made)
np.save('do_swaps/new_pointings_arrays/' + folder + '/costs', costs)

# %%
new_pointings_arr = np.load('do_swaps/new_pointings_arrays/' + folder + '/new_pointings_arr.npy')
#Save simlib file under new name for different variables and then change .input file
make_simlib(new_pointings_arr, 'simlibs/new_' + folder + '.simlib')

# %%
fin = open("input_sample.INPUT")
fout = open("input.INPUT", "wt")
for line in fin:
    fout.write( line.replace('SIMLIB_FILE:  simlibs/', 'SIMLIB_FILE:  simlibs/new_' + folder + '.simlib') )
fin.close()
fout.close()

# %%
DIR = '/data/des41.b/data/SNDATA_ROOT/SIM/GW170817_AT2017gfo_LSST_WFD/'
#get KN locations of simulated events in snana
file_count = len([f for f in os.walk(DIR).next()[2] if f[-4:] == ".DAT"])

os.chdir('/data/des41.a/data/jaortiz/snana-test/')
summary = np.load('do_swaps/new_pointings_arrays/' + folder + '/summary.npy')
summary[4] = file_count
print file_count
summary[5] = 21
np.save('do_swaps/new_pointings_arrays/' + folder + '/summary.npy', summary)
# Out:
# 429

# %%
subprocess.call(["rm", "input.INPUT"])

simlib = '/data/des41.a/data/jaortiz/snana-test/simlibs/new_' + folder + '.simlib'
#all_KN variable is use all KN? Takes either 'yes' or 'no'
all_KN = 'no'
time_taken, KN_locations = make_histogram_vars(simlib, all_KN)

os.chdir('/data/des41.a/data/jaortiz/snana-test/')

np.save('do_swaps/new_pointings_arrays/' + folder + '/time_taken.npy', time_taken)
np.save('do_swaps/new_pointings_arrays/' + folder + '/KN_locations.npy', KN_locations)
# Out:
# Number of LSST pointings:  2083758
# Number of KN observed by snana:  339
# 0
# 50
# 100
# 150
# 200
# 250
# 300
